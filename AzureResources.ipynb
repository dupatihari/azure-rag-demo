# %%
# !az version
# Out:
# {
#   "azure-cli": "2.82.0",
#   "azure-cli-core": "2.82.0",
#   "azure-cli-telemetry": "1.1.0",
#   "extensions": {}
# }

# %%
# !az login --tenant e0f12f12-5d5c-4db1-83a6-96f2af264d06
# Out:
# [
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "e0f12f12-5d5c-4db1-83a6-96f2af264d06",
#     "id": "2a9d785a-fad6-428d-ac9b-82549cd68267",
#     "isDefault": true,
#     "managedByTenants": [],
#     "name": "Visual Studio Premium with MSDN",
#     "state": "Enabled",
#     "tenantId": "e0f12f12-5d5c-4db1-83a6-96f2af264d06",
#     "user": {
#       "name": "hariuphari@hotmail.com",
#       "type": "user"
#     }
#   }
# ]
# WARNING: Select the account you want to log in with. For more information on login with Azure CLI, see https://go.microsoft.com/fwlink/?linkid=2271136

# %%
# !az account list --output table
# Out:
# Name                             CloudName    SubscriptionId                        TenantId                              State    IsDefault
# -------------------------------  -----------  ------------------------------------  ------------------------------------  -------  -----------
# Visual Studio Premium with MSDN  AzureCloud   2a9d785a-fad6-428d-ac9b-82549cd68267  e0f12f12-5d5c-4db1-83a6-96f2af264d06  Enabled  True

# %%
# !az account set --subscription "2a9d785a-fad6-428d-ac9b-82549cd68267"

# %%
# !az group create \
  --name rg-rag-demo \
  --location uksouth
# Out:
# {
#   "id": "/subscriptions/2a9d785a-fad6-428d-ac9b-82549cd68267/resourceGroups/rg-rag-demo",
#   "location": "uksouth",
#   "managedBy": null,
#   "name": "rg-rag-demo",
#   "properties": {
#     "provisioningState": "Succeeded"
#   },
#   "tags": null,
#   "type": "Microsoft.Resources/resourceGroups"
# }

# %%
# !az storage account create \
  --name stragdemouks01 \
  --resource-group rg-rag-demo \
  --location uksouth \
  --sku Standard_LRS \
  --kind StorageV2
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code CDQ6NBXU6 to authenticate.
# ERROR: AADSTS70016: OAuth 2.0 device flow error. Authorization is pending. Continue polling. Trace ID: 44c14efe-6f48-4919-8de5-77389cd60b00 Correlation ID: 7d09d720-0ab6-4a96-8e2a-c20c66f319ca Timestamp: 2026-01-16 16:16:03Z
# Run the command below to authenticate interactively; additional arguments may be added as needed:
# az logout
# az login
# {
#   "accessTier": "Hot",
#   "accountMigrationInProgress": null,
#   "allowBlobPublicAccess": false,
#   "allowCrossTenantReplication": false,
#   "allowSharedKeyAccess": null,
#   "allowedCopyScope": null,
#   "azureFilesIdentityBasedAuthentication": null,
#   "blobRestoreStatus": null,
#   "creationTime": "2026-01-16T16:15:56.876924+00:00",
#   "customDomain": null,
#   "defaultToOAuthAuthentication": null,
#   "dnsEndpointType": null,
#   "dualStackEndpointPreference": null,
#   "enableExtendedGroups": null,
# ...

# %%
# !az storage container create \
  --name campaign-docs \
  --account-name stragdemouks01 \
  --auth-mode login
# Out:
# {
#   "created": true
# }

# %%
# !az search service create \
  --name rag-demo-search-campaign-docs \
  --resource-group rg-rag-demo \
  --location uksouth \
  --sku Basic
# Out:
# {
#   "authOptions": {
#     "apiKeyOnly": {}
#   },
#   "computeType": "Default",
#   "dataExfiltrationProtections": [],
#   "disableLocalAuth": false,
#   "encryptionWithCmk": {
#     "encryptionComplianceStatus": "Compliant",
#     "enforcement": "Unspecified"
#   },
#   "endpoint": "https://rag-demo-search-campaign-docs.search.windows.net",
#   "hostingMode": "default",
#   "id": "/subscriptions/2a9d785a-fad6-428d-ac9b-82549cd68267/resourceGroups/rg-rag-demo/providers/Microsoft.Search/searchServices/rag-demo-search-campaign-docs",
#   "location": "UK South",
#   "name": "rag-demo-search-campaign-docs",
#   "networkRuleSet": {
#     "bypass": "None",
#     "ipRules": []
#   },
#   "partitionCount": 1,
#   "privateEndpointConnections": [],
#   "provisioningState": "succeeded",
#   "publicNetworkAccess": "Enabled",
#   "replicaCount": 1,
#   "resourceGroup": "rg-rag-demo",
#   "semanticSearch": "free",
#   "sharedPrivateLinkResources": [],
#   "sku": {
#     "name": "basic"
#   },
# ...
