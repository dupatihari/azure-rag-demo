# %%
# !az version
# Out:
# /opt/homebrew/Cellar/azure-cli/2.82.0/libexec/lib/python3.13/site-packages/azure/batch/models/_models.py:9067: SyntaxWarning: invalid escape sequence '\ '
#   """The source port ranges to match for the rule. Valid values are '\ *' (for all ports 0 - 65535),
# /opt/homebrew/Cellar/azure-cli/2.82.0/libexec/lib/python3.13/site-packages/azure/batch/models/_models.py:9235: SyntaxWarning: invalid escape sequence '\ '
#   using brackets (for example abc[\ *] would match a file named abc*\ ). Note that both and / are
# {
#   "azure-cli": "2.82.0",
#   "azure-cli-core": "2.82.0",
#   "azure-cli-telemetry": "1.1.0",
#   "extensions": {}
# }

# %%
# !az login --tenant e0f12f12-5d5c-4db1-83a6-96f2af264d06
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().system('az login --tenant e0f12f12-5d5c-4db1-83a6-96f2af264d06')
#
# Cell In[3], line 1
# ----> 1 get_ipython().system('az login --tenant e0f12f12-5d5c-4db1-83a6-96f2af264d06')
#
# File _pydevd_bundle\\pydevd_cython.pyx:1697, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\\pydevd_cython.pyx:634, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1112, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1090, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:494, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# ...

# %%
# !az account list --output table
# Out:
# 113.48s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# A few accounts are skipped as they don't have 'Enabled' state. Use '--all' to display them.
# Name                             CloudName    SubscriptionId                        TenantId                              State    IsDefault
# -------------------------------  -----------  ------------------------------------  ------------------------------------  -------  -----------
# Visual Studio Premium with MSDN  AzureCloud   2a9d785a-fad6-428d-ac9b-82549cd68267  e0f12f12-5d5c-4db1-83a6-96f2af264d06  Enabled  True
# Azure Foundry Subscription       AzureCloud   730d7018-4130-4fe9-9c4c-65df25700eb0  e0f12f12-5d5c-4db1-83a6-96f2af264d06  Enabled  False

# %%
# !az account set --subscription "2a9d785a-fad6-428d-ac9b-82549cd68267"
# Out:
# 122.20s - pydevd: Sending message related to process being replaced timed-out after 5 seconds

# %%
# !az group create \
  --name rg-rag-demo \
  --location uksouth
# Out:
# {
#   "id": "/subscriptions/2a9d785a-fad6-428d-ac9b-82549cd68267/resourceGroups/rg-rag-demo",
#   "location": "uksouth",
#   "managedBy": null,
#   "name": "rg-rag-demo",
#   "properties": {
#     "provisioningState": "Succeeded"
#   },
#   "tags": null,
#   "type": "Microsoft.Resources/resourceGroups"
# }

# %%
# !az storage account create \
  --name stragdemouks01 \
  --resource-group rg-rag-demo \
  --location uksouth \
  --sku Standard_LRS \
  --kind StorageV2
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code CDQ6NBXU6 to authenticate.
# ERROR: AADSTS70016: OAuth 2.0 device flow error. Authorization is pending. Continue polling. Trace ID: 44c14efe-6f48-4919-8de5-77389cd60b00 Correlation ID: 7d09d720-0ab6-4a96-8e2a-c20c66f319ca Timestamp: 2026-01-16 16:16:03Z
# Run the command below to authenticate interactively; additional arguments may be added as needed:
# az logout
# az login
# {
#   "accessTier": "Hot",
#   "accountMigrationInProgress": null,
#   "allowBlobPublicAccess": false,
#   "allowCrossTenantReplication": false,
#   "allowSharedKeyAccess": null,
#   "allowedCopyScope": null,
#   "azureFilesIdentityBasedAuthentication": null,
#   "blobRestoreStatus": null,
#   "creationTime": "2026-01-16T16:15:56.876924+00:00",
#   "customDomain": null,
#   "defaultToOAuthAuthentication": null,
#   "dnsEndpointType": null,
#   "dualStackEndpointPreference": null,
#   "enableExtendedGroups": null,
# ...

# %%
# !az storage container create \
  --name campaign-docs \
  --account-name stragdemouks01 \
  --auth-mode login
# Out:
# {
#   "created": true
# }

# %%
# !az search service create \
  --name rag-demo-search-campaign-docs \
  --resource-group rg-rag-demo \
  --location uksouth \
  --sku Basic
# Out:
# {
#   "authOptions": {
#     "apiKeyOnly": {}
#   },
#   "computeType": "Default",
#   "dataExfiltrationProtections": [],
#   "disableLocalAuth": false,
#   "encryptionWithCmk": {
#     "encryptionComplianceStatus": "Compliant",
#     "enforcement": "Unspecified"
#   },
#   "endpoint": "https://rag-demo-search-campaign-docs.search.windows.net",
#   "hostingMode": "default",
#   "id": "/subscriptions/2a9d785a-fad6-428d-ac9b-82549cd68267/resourceGroups/rg-rag-demo/providers/Microsoft.Search/searchServices/rag-demo-search-campaign-docs",
#   "location": "UK South",
#   "name": "rag-demo-search-campaign-docs",
#   "networkRuleSet": {
#     "bypass": "None",
#     "ipRules": []
#   },
#   "partitionCount": 1,
#   "privateEndpointConnections": [],
#   "provisioningState": "succeeded",
#   "publicNetworkAccess": "Enabled",
#   "replicaCount": 1,
#   "resourceGroup": "rg-rag-demo",
#   "semanticSearch": "free",
#   "sharedPrivateLinkResources": [],
#   "sku": {
#     "name": "basic"
#   },
# ...

# %%
# !az group show -n rg-rag-demo -o table
# Out:
# 469.98s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Location    Name
# ----------  -----------
# uksouth     rg-rag-demo

# %%
# !az storage account create \
  --name strfuncdemouks01 \
  --resource-group rg-rag-demo \
  --location uksouth \
  --sku Standard_LRS \
  --kind StorageV2
# Out:
# 520.29s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# {/ Finished ....
#   "accessTier": "Hot",
#   "accountMigrationInProgress": null,
#   "allowBlobPublicAccess": false,
#   "allowCrossTenantReplication": false,
#   "allowSharedKeyAccess": null,
#   "allowedCopyScope": null,
#   "azureFilesIdentityBasedAuthentication": null,
#   "blobRestoreStatus": null,
#   "creationTime": "2026-01-17T12:44:07.531574+00:00",
#   "customDomain": null,
#   "defaultToOAuthAuthentication": null,
#   "dnsEndpointType": null,
#   "dualStackEndpointPreference": null,
#   "enableExtendedGroups": null,
#   "enableHttpsTrafficOnly": true,
#   "enableNfsV3": null,
#   "encryption": {
#     "encryptionIdentity": null,
#     "keySource": "Microsoft.Storage",
#     "keyVaultProperties": null,
#     "requireInfrastructureEncryption": null,
#     "services": {
#       "blob": {
#         "enabled": true,
#         "keyType": "Account",
# ...

# %%
# !az functionapp create \
  --name func-campaign-insights-uks01 \
  --resource-group rg-rag-demo \
  --storage-account strfuncdemouks01 \
  --consumption-plan-location uksouth \
  --runtime python \
  --runtime-version 3.11 \
  --functions-version 4 \
  --os-type Linux
# Out:
# 634.33s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Your Linux function app 'func-campaign-insights-uks01', that uses a consumption plan has been successfully created but is not active until content is published using Azure Portal or the Functions Core Tools.
#  \ Finished ....Application Insights "func-campaign-insights-uks01" was created for this Function App. You can visit https://portal.azure.com/#resource/subscriptions/2a9d785a-fad6-428d-ac9b-82549cd68267/resourceGroups/rg-rag-demo/providers/microsoft.insights/components/func-campaign-insights-uks01/overview to view your Application Insights component
# {
#   "autoGeneratedDomainNameLabelScope": null,
#   "availabilityState": "Normal",
#   "clientAffinityEnabled": false,
#   "clientAffinityPartitioningEnabled": null,
#   "clientAffinityProxyEnabled": false,
#   "clientCertEnabled": false,
#   "clientCertExclusionPaths": null,
#   "clientCertMode": "Required",
#   "cloningInfo": null,
# ...

# %%
# !az functionapp config appsettings set \
  --name func-campaign-insights-uks01 \
  --resource-group rg-rag-demo \
  --settings \
  AZURE_SEARCH_ENDPOINT="https://rag-demo-search-campaign-docs.search.windows.net" \
  AZURE_SEARCH_INDEX="campaign-index" \
  AZURE_SEARCH_API_KEY="DUMMY_SEARCH_KEY" \
  AZURE_INFERENCE_ENDPOINT="https://rag-demo-project-resource.services.ai.azure.com/models" \
  AZURE_INFERENCE_KEY="DUMMY_FOUNDRY_KEY" \
  AZURE_INFERENCE_MODEL="gpt-4o-mini" \
  AZURE_INFERENCE_API_VERSION="2024-05-01-preview"
# Out:
# 897.53s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# [
#   {
#     "name": "FUNCTIONS_WORKER_RUNTIME",
#     "slotSetting": false,
#     "value": null
#   },
#   {
#     "name": "FUNCTIONS_EXTENSION_VERSION",
#     "slotSetting": false,
#     "value": null
#   },
#   {
#     "name": "AzureWebJobsStorage",
#     "slotSetting": false,
#     "value": null
#   },
#   {
#     "name": "WEBSITE_CONTENTAZUREFILECONNECTIONSTRING",
#     "slotSetting": false,
#     "value": null
#   },
#   {
#     "name": "WEBSITE_CONTENTSHARE",
#     "slotSetting": false,
#     "value": null
#   },
#   {
#     "name": "APPLICATIONINSIGHTS_CONNECTION_STRING",
#     "slotSetting": false,
#     "value": null
#   },
#   {
#     "name": "AZURE_SEARCH_ENDPOINT",
#     "slotSetting": false,
#     "value": null
#   },
#   {
#     "name": "AZURE_SEARCH_INDEX",
#     "slotSetting": false,
#     "value": null
#   },
#   {
#     "name": "AZURE_SEARCH_API_KEY",
# ...
